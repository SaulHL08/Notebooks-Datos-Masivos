# %% [markdown]
# <a href="https://colab.research.google.com/github/SaulHL08/Notebooks-Datos-Masivos/blob/main/BostonPCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Boston.csv')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_cols = df.select_dtypes('number').columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(df)
# Out:
# PCA()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.45411314 0.11092943 0.10806424 0.05952228 0.0589396  0.04559293
#  0.03863886 0.02798412 0.02343864 0.01712409 0.01672187 0.01416745
#  0.01195235 0.00879422 0.00401679]

# %%
df_pca = pca.transform(df)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Número de componentes')
plt.ylabel('Varianza explicada')
plt.title('PCA en datos de Boston')
plt.grid()
plt.show()

# %%
plt.scatter(df_pca[:,0], df_pca[:,1])
plt.title('PCA de datos de Boston')
plt.xlabel('Componente principal 1')
plt.ylabel('Componente principal 2')
plt.grid()
plt.show()
